# %% [markdown]
# Utility notebook for plotting data.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('part-a2/resnet50_cifar10.csv')
df = df.drop(columns=['epoch'])
df.head()
# Out:
#    batch      loss  accuracy
# 0    100  0.585643  0.800625
# 1    200  0.585091  0.793750
# 2    300  0.599921  0.799375
# 3    400  0.551229  0.811562
# 4    500  0.593399  0.793125

# %%
dfs = []
titles = ['resnet50_cifar10', 'resnet50_cifar100', 'resnet50_tiny_imagenet', 'vgg19_cifar10', 'vgg19_cifar100', 'vgg19_tiny_imagenet']

dfs.append(df)
dfs.append(pd.read_csv('part-a2/resnet50_cifar100.csv'))
dfs.append(pd.read_csv('part-a2/resnet50_tiny_imagenet.csv'))
dfs.append(pd.read_csv('part-a2/vgg19_cifar10.csv'))
dfs.append(pd.read_csv('part-a2/vgg19_cifar100.csv'))
dfs.append(pd.read_csv('part-a2/vgg19_tiny_imagenet.csv'))

len(dfs)
# Out:
# 6

# %%
for i, df in enumerate(dfs):
    # Creating the plot
    plt.figure(figsize=(10, 6))

    # Plotting the loss and accuracy
    sns.lineplot(data=df, x='batch', y='loss', label='Loss', marker='o')
    sns.lineplot(data=df, x='batch', y='accuracy', label='Accuracy', marker='o')

    # Setting titles and labels
    plt.title(f'Training Progress - {titles[i]}')
    plt.xlabel('Batch Number')
    plt.ylabel('Value')

    # Adding vertical lines at each new epoch (every 100 batches)
    epoch_starts = np.arange(100, df['batch'].max() + 100, 100)
    for epoch in epoch_starts:
        plt.axvline(x=epoch, color='grey', linestyle='--', linewidth=1)

    plt.legend()
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('part-a2/test_perf.csv')
df.head()
# Out:
#     model         dataset  test_loss  test_acc
# 0  resnet  tiny_image_net   1.827040    0.6016
# 1  resnet         cifar10   2.374048    0.0802
# 2  resnet        cifar100   1.652995    0.5761
# 3   vgg19         cifar10   0.527831    0.8614
# 4   vgg19        cifar100   1.945256    0.4981

# %%
# Setting up the matplotlib figure
plt.figure(figsize=(14, 6))

# Plot for test_loss
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st subplot
sns.barplot(x='dataset', y='test_loss', hue='model', data=df)
plt.title('Test Loss by Dataset and Model')
plt.xlabel('Dataset')
plt.ylabel('Test Loss')

# Plot for test_acc
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd subplot
sns.barplot(x='dataset', y='test_acc', hue='model', data=df)
plt.title('Test Accuracy by Dataset and Model')
plt.xlabel('Dataset')
plt.ylabel('Test Accuracy')

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Assuming you have the file paths to your images
guidance_image_path = 'part-b-style-transfer/style_guidance_fire.jpeg'
# guidance_image_path = 'part-b-style-transfer/style_guidance_flower.jpeg'
# guidance_image_path = 'part-b-style-transfer/style_guidance_vase.jpeg'
# guidance_image_path = 'part-b-style-transfer/style_guidance_yarn.jpeg'

reference_image_path = '/Users/odai/Downloads/images/within_cells_interlined.jpeg'

output_image_path = 'part-b-style-transfer/output_withincellsinterlinked_fire_2024-05-08_20-17-23.png'

# Load the images
reference_image = mpimg.imread(reference_image_path)
guidance_image = mpimg.imread(guidance_image_path)
output_image = mpimg.imread(output_image_path)

# Create a figure to display the images
fig, ax = plt.subplots(1, 3, figsize=(15, 5))  # Adjust the figsize as needed

# Display each image on its corresponding subplot
ax[0].imshow(reference_image)
ax[0].set_title('Reference Subject Image')
ax[0].axis('off')  # Turn off axis

ax[1].imshow(guidance_image)
ax[1].set_title('Guidance Image')
ax[1].axis('off')  # Turn off axis

ax[2].imshow(output_image)
ax[2].set_title('Output Image')
ax[2].axis('off')  # Turn off axis

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Combine all results CSVs to a single Excel file

# %%
import pandas as pd
import os

# %%
fp = './results'

# Get the list of CSV files
csv_files = [f for f in os.listdir(fp) if f.endswith('.csv')]
csv_files
# Out:
# ['resnet50_cifar100.csv',
#  'vgg19_cifar100.csv',
#  'vgg19_tiny_imagenet.csv',
#  'resnet50_cifar10.csv',
#  'resnet50_tiny_imagenet.csv',
#  'test_perf.csv',
#  'a1_results.csv',
#  'vgg19_cifar10.csv']

# %%
# Create a Pandas Excel writer using openpyxl as the engine
writer = pd.ExcelWriter('results.xlsx', engine='openpyxl')

# Write each CSV file to a separate worksheet
for csv_file in csv_files:
    df = pd.read_csv(os.path.join(fp, csv_file))
    # Remove '.csv' from the filename to use as sheet name
    sheet_name = csv_file[:-4]
    df.to_excel(writer, sheet_name=sheet_name, index=False)

# Save the Excel file
writer.close()
